# %% [markdown]
# ## PROYECTO DE ANÁLISIS DE DATOS DE FÚTBOL
# ### ASIGNATURA: MACHINE LEARNING
# #### Autores: Manuel García Romero y Rafael Delgado Martínez

# %%
import numpy as np

import pandas as pd

import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib.patches import Arc
import seaborn as sns

from statsbombpy import sb

from mplsoccer import Pitch, VerticalPitch, FontManager

from scipy.ndimage import gaussian_filter

from matplotlib import rcParams
import cmasher as cmr

from seaborn import kdeplot, distplot
# %matplotlib inline

# %%
#Competiciones de statsbomb, nos quedaremos con la FA Women's Super League
comps = sb.competitions()
comps.head()
# Out:
# credentials were not supplied. open data access only
#    competition_id  season_id country_name  competition_name  \
# 0              16          4       Europe  Champions League
# 1              16          1       Europe  Champions League
# 2              16          2       Europe  Champions League
# 3              16         27       Europe  Champions League
# 4              16         26       Europe  Champions League
#
#   competition_gender  competition_youth  competition_international  \
# 0               male              False                      False
# 1               male              False                      False
# 2               male              False                      False
# 3               male              False                      False
# 4               male              False                      False
#
#   season_name               match_updated        match_updated_360  \
# 0   2018/2019  2021-08-27T11:26:39.802832  2021-06-13T16:17:31.694
# 1   2017/2018  2021-08-27T11:26:39.802832  2021-06-13T16:17:31.694
# 2   2016/2017  2021-08-27T11:26:39.802832  2021-06-13T16:17:31.694
# 3   2015/2016  2021-08-27T11:26:39.802832  2021-06-13T16:17:31.694
# 4   2014/2015  2021-08-27T11:26:39.802832  2021-06-13T16:17:31.694
#
#   match_available_360             match_available
# 0                None     2021-07-09T14:06:05.802
# 1                None  2021-01-23T21:55:30.425330
# 2                None            2020-07-29T05:00
# 3                None            2020-07-29T05:00
# 4                None            2020-07-29T05:00

# %%
#Todos los partidos de esta competición, un total de 131 (2020/21)
M = sb.matches(37,90)
M.info()
# Out:
# credentials were not supplied. open data access only
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131 entries, 0 to 130
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   match_id               131 non-null    int64
#  1   match_date             131 non-null    object
#  2   kick_off               131 non-null    object
#  3   competition            131 non-null    object
#  4   season                 131 non-null    object
#  5   home_team              131 non-null    object
#  6   away_team              131 non-null    object
#  7   home_score             131 non-null    int64
#  8   away_score             131 non-null    int64
#  9   match_status           131 non-null    object
#  10  match_status_360       131 non-null    object
#  11  last_updated           131 non-null    object
#  12  last_updated_360       131 non-null    object
#  13  match_week             131 non-null    int64
#  14  competition_stage      131 non-null    object
#  15  stadium                131 non-null    object
#  16  referee                130 non-null    object
#  17  data_version           131 non-null    object
#  18  shot_fidelity_version  131 non-null    object
#  19  xy_fidelity_version    131 non-null    object
# dtypes: int64(4), object(16)
# memory usage: 20.6+ KB

# %%
#Eventos de un partido en concreto
eventos = sb.events(7576)
eventos.info()
'''match_events.columns
match_events = match_events[['team','type','minute','location','pass_end_location','player']]
match_events = match_events[match_events['type']=='Pass']
match_events.head(30)'''
# Out:
# credentials were not supplied. open data access only
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4154 entries, 0 to 4153
# Data columns (total 79 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ball_receipt_outcome            114 non-null    object
#  1   ball_recovery_recovery_failure  2 non-null      object
#  2   carry_end_location              963 non-null    object
#  3   clearance_aerial_won            3 non-null      object
#  4   counterpress                    85 non-null     object
#  5   dribble_outcome                 36 non-null     object
#  6   dribble_overrun                 2 non-null      object
#  7   duel_outcome                    23 non-null     object
#  8   duel_type                       36 non-null     object
#  9   duration                        2641 non-null   float64
#  10  foul_committed_advantage        2 non-null      object
#  11  foul_committed_card             2 non-null      object
#  12  foul_committed_offensive        2 non-null      object
#  13  foul_committed_penalty          1 non-null      object
#  14  foul_committed_type             1 non-null      object
#  15  foul_won_advantage              3 non-null      object
#  16  foul_won_defensive              3 non-null      object
#  17  foul_won_penalty                1 non-null      object
#  18  goalkeeper_body_part            3 non-null      object
#  19  goalkeeper_end_location         14 non-null     object
#  20  goalkeeper_outcome              10 non-null     object
#  21  goalkeeper_position             22 non-null     object
#  22  goalkeeper_technique            8 non-null      object
#  23  goalkeeper_type                 24 non-null     object
#  24  id                              4154 non-null   object
#  25  index                           4154 non-null   int64
#  26  injury_stoppage_in_chain        1 non-null      object
#  27  interception_outcome            18 non-null     object
#  28  location                        4095 non-null   object
#  29  match_id                        4154 non-null   int64
#  30  minute                          4154 non-null   int64
#  31  pass_aerial_won                 9 non-null      object
#  32  pass_angle                      1168 non-null   float64
#  33  pass_assisted_shot_id           13 non-null     object
#  34  pass_backheel                   7 non-null      object
#  35  pass_body_part                  1128 non-null   object
#  36  pass_cross                      19 non-null     object
#  37  pass_cut_back                   1 non-null      object
#  38  pass_deflected                  1 non-null      object
#  39  pass_end_location               1168 non-null   object
#  40  pass_goal_assist                1 non-null      object
#  41  pass_height                     1168 non-null   object
#  42  pass_length                     1168 non-null   float64
#  43  pass_miscommunication           1 non-null      object
#  44  pass_outcome                    136 non-null    object
#  45  pass_recipient                  1146 non-null   object
#  46  pass_shot_assist                12 non-null     object
#  47  pass_switch                     36 non-null     object
#  48  pass_technique                  1 non-null      object
#  49  pass_through_ball               1 non-null      object
#  50  pass_type                       129 non-null    object
#  51  period                          4154 non-null   int64
#  52  play_pattern                    4154 non-null   object
#  53  player                          4103 non-null   object
#  54  player_id                       4103 non-null   float64
#  55  position                        4103 non-null   object
#  56  possession                      4154 non-null   int64
#  57  possession_team                 4154 non-null   object
#  58  possession_team_id              4154 non-null   int64
#  59  related_events                  4021 non-null   object
#  60  second                          4154 non-null   int64
#  61  shot_aerial_won                 1 non-null      object
#  62  shot_body_part                  22 non-null     object
#  63  shot_end_location               22 non-null     object
#  64  shot_first_time                 7 non-null      object
#  65  shot_freeze_frame               21 non-null     object
#  66  shot_key_pass_id                13 non-null     object
#  67  shot_open_goal                  1 non-null      object
#  68  shot_outcome                    22 non-null     object
#  69  shot_statsbomb_xg               22 non-null     float64
#  70  shot_technique                  22 non-null     object
#  71  shot_type                       22 non-null     object
#  72  substitution_outcome            6 non-null      object
#  73  substitution_replacement        6 non-null      object
#  74  tactics                         2 non-null      object
#  75  team                            4154 non-null   object
#  76  timestamp                       4154 non-null   object
#  77  type                            4154 non-null   object
#  78  under_pressure                  1091 non-null   object
# dtypes: float64(5), int64(7), object(67)
# memory usage: 2.5+ MB
# "match_events.columns\nmatch_events = match_events[['team','type','minute','location','pass_end_location','player']]\nmatch_events = match_events[match_events['type']=='Pass']\nmatch_events.head(30)"

# %%
all_events = []
for i in range(0,len(M)):
    print(M.iloc[i]['match_id'])
    all_events.append(sb.events(M.iloc[i]['match_id']))
    
eventosLiga = pd.concat(all_events, ignore_index=True)
# Out:
# 3775648
# credentials were not supplied. open data access only
# 3775609
# credentials were not supplied. open data access only
# 3775633
# credentials were not supplied. open data access only
# 3775570
# credentials were not supplied. open data access only
# 3775581
# credentials were not supplied. open data access only
# 3775579
# credentials were not supplied. open data access only
# 3775544
# credentials were not supplied. open data access only
# 3775622
# credentials were not supplied. open data access only
# 3775553
# credentials were not supplied. open data access only
# 3775584
# credentials were not supplied. open data access only
# 3775618
# credentials were not supplied. open data access only
# 3775641
# credentials were not supplied. open data access only
# 3775636
# credentials were not supplied. open data access only
# 3775653
# credentials were not supplied. open data access only
# 3775654
# credentials were not supplied. open data access only
# 3775643
# credentials were not supplied. open data access only
# 3764237
# credentials were not supplied. open data access only
# 3775594
# credentials were not supplied. open data access only
# 3775560
# credentials were not supplied. open data access only
# 3775624
# credentials were not supplied. open data access only
# 3764240
# credentials were not supplied. open data access only
# 3764233
# credentials were not supplied. open data access only
# 3775585
# credentials were not supplied. open data access only
# 3775593
# credentials were not supplied. open data access only
# 3775602
# credentials were not supplied. open data access only
# 3775620
# credentials were not supplied. open data access only
# 3764232
# credentials were not supplied. open data access only
# 3775559
# credentials were not supplied. open data access only
# 3775606
# credentials were not supplied. open data access only
# 3775567
# credentials were not supplied. open data access only
# 3775638
# credentials were not supplied. open data access only
# 3775607
# credentials were not supplied. open data access only
# 3764230
# credentials were not supplied. open data access only
# 3764241
# credentials were not supplied. open data access only
# 3764235
# credentials were not supplied. open data access only
# 3764239
# credentials were not supplied. open data access only
# 3764236
# credentials were not supplied. open data access only
# 3764231
# credentials were not supplied. open data access only
# 3764234
# credentials were not supplied. open data access only
# 3775543
# credentials were not supplied. open data access only
# 3775551
# credentials were not supplied. open data access only
# 3775540
# credentials were not supplied. open data access only
# 3775550
# credentials were not supplied. open data access only
# 3775545
# credentials were not supplied. open data access only
# 3775556
# credentials were not supplied. open data access only
# 3775575
# credentials were not supplied. open data access only
# 3775562
# credentials were not supplied. open data access only
# 3775561
# credentials were not supplied. open data access only
# 3775582
# credentials were not supplied. open data access only
# 3775558
# credentials were not supplied. open data access only
# 3775552
# credentials were not supplied. open data access only
# 3775557
# credentials were not supplied. open data access only
# 3775564
# credentials were not supplied. open data access only
# 3775569
# credentials were not supplied. open data access only
# 3775548
# credentials were not supplied. open data access only
# 3775568
# credentials were not supplied. open data access only
# 3775563
# credentials were not supplied. open data access only
# 3775555
# credentials were not supplied. open data access only
# 3775549
# credentials were not supplied. open data access only
# 3775572
# credentials were not supplied. open data access only
# 3775577
# credentials were not supplied. open data access only
# 3775541
# credentials were not supplied. open data access only
# 3775588
# credentials were not supplied. open data access only
# 3775586
# credentials were not supplied. open data access only
# 3775592
# credentials were not supplied. open data access only
# 3775580
# credentials were not supplied. open data access only
# 3775591
# credentials were not supplied. open data access only
# 3775590
# credentials were not supplied. open data access only
# 3775571
# credentials were not supplied. open data access only
# 3775589
# credentials were not supplied. open data access only
# 3775578
# credentials were not supplied. open data access only
# 3775596
# credentials were not supplied. open data access only
# 3775576
# credentials were not supplied. open data access only
# 3775574
# credentials were not supplied. open data access only
# 3775573
# credentials were not supplied. open data access only
# 3775597
# credentials were not supplied. open data access only
# 3775611
# credentials were not supplied. open data access only
# 3775628
# credentials were not supplied. open data access only
# 3775612
# credentials were not supplied. open data access only
# 3775627
# credentials were not supplied. open data access only
# 3775644
# credentials were not supplied. open data access only
# 3775637
# credentials were not supplied. open data access only
# 3775631
# credentials were not supplied. open data access only
# 3775621
# credentials were not supplied. open data access only
# 3775615
# credentials were not supplied. open data access only
# 3775610
# credentials were not supplied. open data access only
# 3775616
# credentials were not supplied. open data access only
# 3775632
# credentials were not supplied. open data access only
# 3775629
# credentials were not supplied. open data access only
# 3775619
# credentials were not supplied. open data access only
# 3775600
# credentials were not supplied. open data access only
# 3775605
# credentials were not supplied. open data access only
# 3775626
# credentials were not supplied. open data access only
# 3775614
# credentials were not supplied. open data access only
# 3775603
# credentials were not supplied. open data access only
# 3775625
# credentials were not supplied. open data access only
# 3775613
# credentials were not supplied. open data access only
# 3775598
# credentials were not supplied. open data access only
# 3775601
# credentials were not supplied. open data access only
# 3775630
# credentials were not supplied. open data access only
# 3775651
# credentials were not supplied. open data access only
# 3775635
# credentials were not supplied. open data access only
# 3775650
# credentials were not supplied. open data access only
# 3775647
# credentials were not supplied. open data access only
# 3775659
# credentials were not supplied. open data access only
# 3775657
# credentials were not supplied. open data access only
# 3775649
# credentials were not supplied. open data access only
# 3775645
# credentials were not supplied. open data access only
# 3775639
# credentials were not supplied. open data access only
# 3775642
# credentials were not supplied. open data access only
# 3775646
# credentials were not supplied. open data access only
# 3775655
# credentials were not supplied. open data access only
# 3775640
# credentials were not supplied. open data access only
# 3775658
# credentials were not supplied. open data access only
# 3775623
# credentials were not supplied. open data access only
# 3775566
# credentials were not supplied. open data access only
# 3775546
# credentials were not supplied. open data access only
# 3775547
# credentials were not supplied. open data access only
# 3775587
# credentials were not supplied. open data access only
# 3775595
# credentials were not supplied. open data access only
# 3775604
# credentials were not supplied. open data access only
# 3775634
# credentials were not supplied. open data access only
# 3775617
# credentials were not supplied. open data access only
# 3775565
# credentials were not supplied. open data access only
# 3775583
# credentials were not supplied. open data access only
# 3775542
# credentials were not supplied. open data access only
# 3775608
# credentials were not supplied. open data access only
# 3775599
# credentials were not supplied. open data access only
# 3775554
# credentials were not supplied. open data access only
# 3775652
# credentials were not supplied. open data access only
# 3764238
# credentials were not supplied. open data access only

# %%
eventosLiga.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 443305 entries, 0 to 443304
# Columns: 112 entries, 50_50 to goalkeeper_lost_in_play
# dtypes: float64(5), int64(7), object(100)
# memory usage: 378.8+ MB

# %%
eventosLiga.head()
# Out:
#   50_50 ball_receipt_outcome ball_recovery_recovery_failure block_deflection  \
# 0   NaN                  NaN                            NaN              NaN
# 1   NaN                  NaN                            NaN              NaN
# 2   NaN                  NaN                            NaN              NaN
# 3   NaN                  NaN                            NaN              NaN
# 4   NaN                  NaN                            NaN              NaN
#
#   block_offensive carry_end_location clearance_aerial_won clearance_body_part  \
# 0             NaN                NaN                  NaN                 NaN
# 1             NaN                NaN                  NaN                 NaN
# 2             NaN                NaN                  NaN                 NaN
# 3             NaN                NaN                  NaN                 NaN
# 4             NaN                NaN                  NaN                 NaN
#
#   clearance_head clearance_left_foot  ... goalkeeper_success_in_play  \
# 0            NaN                 NaN  ...                        NaN
# 1            NaN                 NaN  ...                        NaN
# 2            NaN                 NaN  ...                        NaN
# 3            NaN                 NaN  ...                        NaN
# 4            NaN                 NaN  ...                        NaN
#
#   bad_behaviour_card dribble_no_touch shot_follows_dribble  \
# 0                NaN              NaN                  NaN
# 1                NaN              NaN                  NaN
# 2                NaN              NaN                  NaN
# 3                NaN              NaN                  NaN
# 4                NaN              NaN                  NaN
#
#   goalkeeper_saved_to_post half_start_late_video_start  \
# 0                      NaN                         NaN
# 1                      NaN                         NaN
# 2                      NaN                         NaN
# 3                      NaN                         NaN
# 4                      NaN                         NaN
#
#    goalkeeper_shot_saved_to_post shot_saved_to_post goalkeeper_lost_out  \
# 0                            NaN                NaN                 NaN
# 1                            NaN                NaN                 NaN
# 2                            NaN                NaN                 NaN
# 3                            NaN                NaN                 NaN
# 4                            NaN                NaN                 NaN
#
#   goalkeeper_lost_in_play
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
#
# [5 rows x 112 columns]

# %%
eventosLiga.isna().sum()
# Out:
# 50_50                             443111
# ball_receipt_outcome              421570
# ball_recovery_recovery_failure    441928
# block_deflection                  443169
# block_offensive                   443202
#                                    ...
# half_start_late_video_start       443301
# goalkeeper_shot_saved_to_post     443295
# shot_saved_to_post                443296
# goalkeeper_lost_out               443304
# goalkeeper_lost_in_play           443304
# Length: 112, dtype: int64

# %%
#Mostramos algo de información útil:
fig, ax = plt.subplots()

count=eventosLiga['type']
types = count.unique()[2:20]

values=count.value_counts()
values = values[2:20]

plt.barh(types,values)
plt.title('Ocurrencia de eventos')
plt.ylabel('Tipo')
plt.xlabel('Cantidad')
plt.show()

# %%
#Mostramos algo de información útil:
def my_fmt(x):
    print(x)
    return '{:.4f}%\n'.format(x, total*x/100)

count=eventosLiga['team']
total = len(count.value_counts())
pie = count.value_counts().plot.pie(autopct=my_fmt)
print(pie)
plt.show()
# Out:
# 11.0463447868824
# 10.656094551086426
# 10.053123533725739
# 9.093964844942093
# 8.749957382678986
# 8.16773995757103
# 7.621840387582779
# 7.554392516613007
# 7.391750812530518
# 7.052029669284821
# 6.409131735563278
# 6.203629449009895
# AxesSubplot(0.260833,0.125;0.503333x0.755)

# %%
#Tipos de pases
count=eventosLiga.loc[eventosLiga['type'] == 'Pass']
count=count['pass_height']
pie = count.value_counts().plot.pie()
print(pie)
plt.show()
# Out:
# AxesSubplot(0.260833,0.125;0.503333x0.755)

# %%
#Pases a tiros
count=eventosLiga.loc[eventosLiga['type'] == 'Pass']
count=count['pass_shot_assist']
pie = count.value_counts(dropna=False).plot.pie()
print(pie)
plt.show()
# Out:
# AxesSubplot(0.260833,0.125;0.503333x0.755)

# %%
#Asistencias
count=eventosLiga.loc[eventosLiga['type'] == 'Pass']
count=count['pass_goal_assist']
pie = count.value_counts(dropna=False).plot.pie()
print(pie)
plt.show()
# Out:
# AxesSubplot(0.260833,0.125;0.503333x0.755)

# %%
#Mostramos algo de información útil:
count=eventosLiga['dribble_outcome']
histogram = count.value_counts().plot.pie()
print(histogram)
plt.show()
# Out:
# AxesSubplot(0.260833,0.125;0.503333x0.755)

# %%
#Mostramos algo de información útil:
count=eventosLiga['shot_outcome']
histogram = count.value_counts().plot.bar()
print(histogram)
plt.show()
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
#Mostramos algo de información útil:
count=eventosLiga['period']
histogram = count.value_counts().plot.pie()
print(histogram)
plt.show()
# Out:
# AxesSubplot(0.260833,0.125;0.503333x0.755)

# %%
kdeplot(eventosLiga['minute'],clip=(0.0, 90.0))
# Out:
# <AxesSubplot:xlabel='minute', ylabel='Density'>

# %%
eventosLiga.describe()
# Out:
#             duration          index      match_id         minute  \
# count  330922.000000  443305.000000  4.433050e+05  443305.000000
# mean        1.254296    1705.113455  3.774558e+06      45.511018
# std         1.402620     998.531251  3.278090e+03      27.252507
# min         0.000000       1.000000  3.764230e+06       0.000000
# 25%         0.195661     847.000000  3.775560e+06      22.000000
# 50%         1.047893    1693.000000  3.775593e+06      45.000000
# 75%         1.755570    2539.000000  3.775626e+06      69.000000
# max       158.659160    4152.000000  3.775659e+06     102.000000
#
#           pass_angle    pass_length         period      player_id  \
# count  121382.000000  121382.000000  443305.000000  441379.000000
# mean        0.005815      21.404722       1.496642   19135.780289
# std         1.526803      13.897759       0.499989   12779.792748
# min        -3.136667       0.000000       1.000000    4633.000000
# 25%        -1.112720      11.677756       1.000000   10192.000000
# 50%        -0.009824      17.827227       1.000000   15648.000000
# 75%         1.130954      27.418971       2.000000   25453.000000
# max         3.141593     115.342445       2.000000  105102.000000
#
#           possession  possession_team_id         second  shot_statsbomb_xg
# count  443305.000000       443305.000000  443305.000000        3248.000000
# mean       98.776226         1082.265512      29.288684           0.117481
# std        57.972232          453.394005      17.417091           0.150225
# min         1.000000          746.000000       0.000000           0.000000
# 25%        49.000000          965.000000      14.000000           0.027917
# 50%        97.000000          969.000000      29.000000           0.056342
# 75%       147.000000          973.000000      44.000000           0.138513
# max       244.000000         2647.000000      59.000000           0.912725

# %%
#formateamos posición
eventosLiga[['x', 'y']] = eventosLiga['location'].apply(pd.Series)
eventosLiga.columns
# Out:
# Index(['50_50', 'ball_receipt_outcome', 'ball_recovery_recovery_failure',
#        'block_deflection', 'block_offensive', 'carry_end_location',
#        'clearance_aerial_won', 'clearance_body_part', 'clearance_head',
#        'clearance_left_foot',
#        ...
#        'dribble_no_touch', 'shot_follows_dribble', 'goalkeeper_saved_to_post',
#        'half_start_late_video_start', 'goalkeeper_shot_saved_to_post',
#        'shot_saved_to_post', 'goalkeeper_lost_out', 'goalkeeper_lost_in_play',
#        'x', 'y'],
#       dtype='object', length=114)

# %%
equipos = ['Arsenal WFC']
  
# selecting rows
df_filtrado = eventosLiga.loc[eventosLiga['team'].isin(equipos)]

pasesArsenal=df_filtrado.loc[df_filtrado['type'] == 'Pass']
presionArsenal=df_filtrado.loc[df_filtrado['type'] == 'Pressure']

# %%
Arsenal=M.loc[M['home_team'] == 'Arsenal WFC']
Arsenal
# Out:
#      match_id  match_date      kick_off                        competition  \
# 1     3775609  2021-04-28  20:30:00.000  England - FA Women's Super League
# 9     3775584  2020-12-06  15:00:00.000  England - FA Women's Super League
# 18    3775560  2021-05-09  15:30:00.000  England - FA Women's Super League
# 21    3764233  2020-09-06  13:30:00.000  England - FA Women's Super League
# 27    3775559  2020-12-20  13:30:00.000  England - FA Women's Super League
# 51    3775557  2021-04-25  15:00:00.000  England - FA Women's Super League
# 63    3775586  2020-10-18  15:30:00.000  England - FA Women's Super League
# 75    3775597  2021-03-19  19:30:00.000  England - FA Women's Super League
# 79    3775627  2020-11-15  15:30:00.000  England - FA Women's Super League
# 90    3775600  2021-02-07  15:30:00.000  England - FA Women's Super League
# 105   3775657  2020-10-04  15:00:00.000  England - FA Women's Super League
#
#         season    home_team                   away_team  home_score  \
# 1    2020/2021  Arsenal WFC         West Ham United LFC           2
# 9    2020/2021  Arsenal WFC         Birmingham City WFC           3
# 18   2020/2021  Arsenal WFC                 Aston Villa           0
# 21   2020/2021  Arsenal WFC                 Reading WFC           6
# 27   2020/2021  Arsenal WFC                 Everton LFC           4
# 51   2020/2021  Arsenal WFC  Brighton & Hove Albion WFC           2
# 63   2020/2021  Arsenal WFC     Tottenham Hotspur Women           6
# 75   2020/2021  Arsenal WFC           Manchester United           2
# 79   2020/2021  Arsenal WFC                 Chelsea FCW           1
# 90   2020/2021  Arsenal WFC         Manchester City WFC           1
# 105  2020/2021  Arsenal WFC            Bristol City WFC           3
#
#      away_score match_status match_status_360                last_updated  \
# 1             0    available        scheduled     2021-05-28T15:32:57.267
# 9             0    available        scheduled  2021-04-28T07:08:31.973962
# 18            0    available        scheduled  2021-05-12T09:12:43.050169
# 21            1    available        scheduled  2020-09-10T19:07:18.289932
# 27            0    available        scheduled     2021-06-12T22:33:04.997
# 51            0    available        scheduled  2021-04-26T07:59:59.353501
# 63            1    available        scheduled  2020-10-27T15:24:31.224914
# 75            0    available        scheduled     2021-06-21T22:10:21.903
# 79            1    available        scheduled  2020-11-16T22:41:10.963969
# 90            2    available        scheduled  2021-02-09T20:53:49.805431
# 105           1    available        scheduled  2020-10-23T20:06:15.042022
#
#             last_updated_360  match_week competition_stage       stadium  \
# 1    2021-06-13T16:17:31.694          13    Regular Season  Meadow Park
# 9    2021-06-13T16:17:31.694           8    Regular Season  Meadow Park
# 18   2021-06-13T16:17:31.694          22    Regular Season  Meadow Park
# 21   2021-06-13T16:17:31.694           1    Regular Season  Meadow Park
# 27   2021-06-13T16:17:31.694          10    Regular Season  Meadow Park
# 51   2021-06-13T16:17:31.694          20    Regular Season  Meadow Park
# 63   2021-06-13T16:17:31.694           5    Regular Season  Meadow Park
# 75   2021-06-13T16:17:31.694          17    Regular Season  Meadow Park
# 79   2021-06-13T16:17:31.694           7    Regular Season  Meadow Park
# 90   2021-06-13T16:17:31.694          14    Regular Season  Meadow Park
# 105  2021-06-13T16:17:31.694           3    Regular Season  Meadow Park
#
#                   referee data_version shot_fidelity_version  \
# 1           Emily Heaslip        1.1.0                     2
# 9    Christina Hattersley        1.1.0                     2
# 18          Abigail Byrne        1.1.0                     2
# 21              Amy Fearn        1.1.0                     2
# 27           Helen Conley        1.1.0                     2
# 51              Lisa Benn        1.1.0                     2
# 63          Abigail Byrne        1.1.0                     2
# 75              Amy Fearn        1.1.0                     2
# 79           Kirsty Dowle        1.1.0                     2
# 90           Kirsty Dowle        1.1.0                     2
# 105         Emily Heaslip        1.1.0                     2
#
#     xy_fidelity_version
# 1                     2
# 9                     2
# 18                    2
# 21                    2
# 27                    2
# 51                    2
# 63                    2
# 75                    2
# 79                    2
# 90                    2
# 105                   2

# %%
pasesArsenal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13909 entries, 6 to 441050
# Columns: 114 entries, 50_50 to y
# dtypes: float64(7), int64(7), object(100)
# memory usage: 12.2+ MB

# %%
df_tirosManchester = eventosLiga.loc[eventosLiga['team'] == 'Manchester City WFC']
tirosManchester=df_tirosManchester.loc[df_tirosManchester['type'] == 'Shot']

# %%
# setup pitch
pitch = Pitch(pitch_type='statsbomb', line_zorder=2,
              pitch_color='#22312b', line_color='#efefef')
# draw
fig, ax = pitch.draw(figsize=(6.6, 4.125))
fig.set_facecolor('#22312b')
bin_statistic = pitch.bin_statistic(presionArsenal.x, presionArsenal.y, statistic='count', bins=(25, 25))
bin_statistic['statistic'] = gaussian_filter(bin_statistic['statistic'], 1)
pcm = pitch.heatmap(bin_statistic, ax=ax, cmap='hot', edgecolors='#22312b')
# Add the colorbar and format off-white
cbar = fig.colorbar(pcm, ax=ax, shrink=0.6)
cbar.outline.set_edgecolor('#efefef')
cbar.ax.yaxis.set_tick_params(color='#efefef')
plt.setp(plt.getp(cbar.ax.axes, 'yticklabels'), color='#efefef')
# Out:
# [None, None, None, None, None, None, None, None, None, None]

# %%
# setup pitch
pitch = Pitch(pitch_type='statsbomb', line_zorder=2,
              pitch_color='#22312b', line_color='#efefef')
# draw
fig, ax = pitch.draw(figsize=(6.6, 4.125))
fig.set_facecolor('#22312b')
bin_statistic = pitch.bin_statistic(tirosManchester.x, tirosManchester.y, statistic='count', bins=(25, 25))
bin_statistic['statistic'] = gaussian_filter(bin_statistic['statistic'], 1)
pcm = pitch.heatmap(bin_statistic, ax=ax, cmap='hot', edgecolors='#22312b')
# Add the colorbar and format off-white
cbar = fig.colorbar(pcm, ax=ax, shrink=0.6)
cbar.outline.set_edgecolor('#efefef')
cbar.ax.yaxis.set_tick_params(color='#efefef')
plt.setp(plt.getp(cbar.ax.axes, 'yticklabels'), color='#efefef')
# Out:
# [None, None, None, None, None, None, None, None, None, None, None, None]

# %%
# setup pitch
pitch = Pitch(pitch_type='statsbomb', line_zorder=2,
              pitch_color='#22312b', line_color='#efefef')
# draw
fig, ax = pitch.draw(figsize=(6.6, 4.125))
fig.set_facecolor('#22312b')
bin_statistic = pitch.bin_statistic(pasesArsenal.x, pasesArsenal.y, statistic='count', bins=(25, 25))
bin_statistic['statistic'] = gaussian_filter(bin_statistic['statistic'], 1)
pcm = pitch.heatmap(bin_statistic, ax=ax, cmap='hot', edgecolors='#22312b')
# Add the colorbar and format off-white
cbar = fig.colorbar(pcm, ax=ax, shrink=0.6)
cbar.outline.set_edgecolor('#efefef')
cbar.ax.yaxis.set_tick_params(color='#efefef')
plt.setp(plt.getp(cbar.ax.axes, 'yticklabels'), color='#efefef')
# Out:
# [None, None, None, None, None, None, None, None]

# %%
import matplotlib.patheffects as path_effects
from matplotlib.colors import LinearSegmentedColormap
# fontmanager for google font (robotto)
robotto_regular = FontManager()

# path effects
path_eff = [path_effects.Stroke(linewidth=1.5, foreground='black'),
            path_effects.Normal()]

# see the custom colormaps example for more ideas on setting colormaps
pearl_earring_cmap = LinearSegmentedColormap.from_list("Pearl Earring - 10 colors",
                                                       ['#15242e', '#4393c4'], N=10)

pitch = VerticalPitch(pitch_type='statsbomb', line_zorder=2, pitch_color='#1e4259')
fig, axs = pitch.grid(endnote_height=0.03, endnote_space=0,
                      title_height=0.08, title_space=0,
                      # Turn off the endnote/title axis. I usually do this after
                      # I am happy with the chart layout and text placement
                      axis=False,
                      grid_height=0.84)
fig.set_facecolor('#1e4259')

bin_x = np.linspace(pitch.dim.left, pitch.dim.right, num=7)
bin_y = np.sort(np.array([pitch.dim.bottom, pitch.dim.six_yard_bottom,
                          pitch.dim.six_yard_top, pitch.dim.top]))
bin_statistic = pitch.bin_statistic(pasesArsenal.x, pasesArsenal.y, statistic='count',
                                    bins=(bin_x, bin_y), normalize=True)
pitch.heatmap(bin_statistic, ax=axs['pitch'], cmap=pearl_earring_cmap, edgecolor='#f9f9f9')
labels3 = pitch.label_heatmap(bin_statistic, color='#dee6ea', fontsize=18,
                              ax=axs['pitch'], ha='center', va='center',
                              str_format='{:.0%}', path_effects=path_eff)

# endnote and title
#axs['endnote'].text(1, 0.5, '@your_twitter_handle', va='center', ha='right', fontsize=15,
#                    fontproperties=robotto_regular.prop, color='#dee6ea')
axs['title'].text(0.5, 0.5, "Distribución de pases del Arsenal WFC", color='#dee6ea',
                  va='center', ha='center', path_effects=path_eff,
                  fontproperties=robotto_regular.prop, fontsize=25)

plt.show()

# %%
cmap = LinearSegmentedColormap.from_list("cmr.ember",
                                                  ['#e3aca7', '#c03a1d'], N=100)

pitch = VerticalPitch(line_color='#000009', line_zorder=2)
fig, ax = pitch.draw(figsize=(4.4, 6.4))
kde = pitch.kdeplot(pasesArsenal.x, pasesArsenal.y, ax=ax,
                    # shade using 100 levels so it looks smooth
                    shade=True, levels=100,
                    # shade the lowest area so it looks smooth
                    # so even if there are no events it gets some color
                    shade_lowest=True,
                    cut=4,  # extended the cut so it reaches the bottom edge
                    cmap=cmr.ember)

# %%
'''Ejemplo de contenido en un evento'''
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(eventosLiga.isna().sum())
    #print(eventosLiga.iloc[1375])
# Out:
# 50_50                               443111
# ball_receipt_outcome                421570
# ball_recovery_recovery_failure      441928
# block_deflection                    443169
# block_offensive                     443202
# carry_end_location                  348937
# clearance_aerial_won                442202
# clearance_body_part                 436384
# clearance_head                      440086
# clearance_left_foot                 442014
# clearance_right_foot                440956
# counterpress                        427787
# dribble_nutmeg                      443080
# dribble_outcome                     438560
# duel_outcome                        437924
# duel_type                           434360
# duration                            112383
# foul_committed_advantage            443070
# foul_committed_card                 443039
# foul_committed_type                 443147
# foul_won_advantage                  443075
# foul_won_defensive                  442560
# goalkeeper_body_part                442365
# goalkeeper_end_location             441236
# goalkeeper_outcome                  441435
# goalkeeper_position                 440049
# goalkeeper_punched_out              443270
# goalkeeper_technique                442106
# goalkeeper_type                     439366
# id                                       0
# index                                    0
# interception_outcome                439782
# location                              3225
# match_id                                 0
# minute                                   0
# off_camera                          440660
# out                                 438829
# pass_aerial_won                     441265
# pass_angle                          321923
# pass_assisted_shot_id               441091
# pass_body_part                      331324
# pass_cross                          440430
# pass_cut_back                       443009
# pass_deflected                      443164
# pass_end_location                   321923
# pass_goal_assist                    443051
# pass_height                         321923
# pass_inswinging                     442696
# pass_length                         321923
# pass_miscommunication               443241
# pass_no_touch                       443222
# pass_outcome                        412571
# pass_outswinging                    443009
# pass_recipient                      330922
# pass_shot_assist                    441345
# pass_straight                       443175
# pass_switch                         440643
# pass_technique                      441635
# pass_through_ball                   442670
# pass_type                           415654
# period                                   0
# play_pattern                             0
# player                                1926
# player_id                             1926
# position                              1926
# possession                               0
# possession_team                          0
# possession_team_id                       0
# related_events                       20793
# second                                   0
# shot_aerial_won                     443011
# shot_body_part                      440057
# shot_end_location                   440057
# shot_first_time                     442193
# shot_freeze_frame                   440086
# shot_key_pass_id                    441091
# shot_one_on_one                     443162
# shot_open_goal                      443265
# shot_outcome                        440057
# shot_statsbomb_xg                   440057
# shot_technique                      440057
# shot_type                           440057
# substitution_outcome                442460
# substitution_replacement            442460
# tactics                             442819
# team                                     0
# timestamp                                0
# type                                     0
# under_pressure                      348464
# dribble_overrun                     443030
# injury_stoppage_in_chain            443168
# clearance_other                     443243
# goalkeeper_shot_saved_off_target    443267
# shot_deflected                      443275
# shot_saved_off_target               443267
# foul_committed_offensive            443233
# foul_committed_penalty              443269
# foul_won_penalty                    443279
# miscontrol_aerial_won               443178
# shot_redirect                       443297
# ball_recovery_offensive             443272
# block_save_block                    443278
# goalkeeper_success_in_play          443299
# bad_behaviour_card                  443286
# dribble_no_touch                    443287
# shot_follows_dribble                443301
# goalkeeper_saved_to_post            443304
# half_start_late_video_start         443301
# goalkeeper_shot_saved_to_post       443295
# shot_saved_to_post                  443296
# goalkeeper_lost_out                 443304
# goalkeeper_lost_in_play             443304
# dtype: int64

# %%
#Jugadoras de la liga que mas pases con ocasion de tiro dan.
