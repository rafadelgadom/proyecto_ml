# %% [markdown]
# ## PROYECTO DE ANÁLISIS DE DATOS DE FÚTBOL
# ### ASIGNATURA: MACHINE LEARNING
# #### Autores: Manuel García Romero y Rafael Delgado Martínez

# %%
from statsbombpy import sb

# %%
comps = sb.competitions()
comps.info()
comps.head()
# Out:
# credentials were not supplied. open data access only
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   competition_id             40 non-null     int64
#  1   season_id                  40 non-null     int64
#  2   country_name               40 non-null     object
#  3   competition_name           40 non-null     object
#  4   competition_gender         40 non-null     object
#  5   competition_youth          40 non-null     bool
#  6   competition_international  40 non-null     bool
#  7   season_name                40 non-null     object
#  8   match_updated              39 non-null     object
#  9   match_updated_360          39 non-null     object
#  10  match_available_360        2 non-null      object
#  11  match_available            39 non-null     object
# dtypes: bool(2), int64(2), object(8)
# ...

# %%
m = sb.matches(43,3)
m = m[m['away_team'] == 'Spain']
m
# Out:
# credentials were not supplied. open data access only
#     match_id  match_date      kick_off                     competition season  \
# 8       7576  2018-06-15  20:00:00.000  International - FIFA World Cup   2018
# 44      7543  2018-06-20  20:00:00.000  International - FIFA World Cup   2018
#
#    home_team away_team  home_score  away_score match_status match_status_360  \
# 8   Portugal     Spain           3           3    available        scheduled
# 44      Iran     Spain           0           1    available        scheduled
#
#                   last_updated         last_updated_360  match_week  \
# 8   2021-12-06T22:30:32.372616  2021-06-13T16:17:31.694           1
# 44            2020-07-29T05:00  2021-06-13T16:17:31.694           2
#
#    competition_stage                    stadium          referee data_version  \
# 8        Group Stage  Olimpiyskiy Stadion Fisht  Gianluca Rocchi        1.0.2
# 44       Group Stage      Kazan' Arena (Kazan')     Andrés Cunha        1.0.2
# ...

# %%
match_events = sb.events(7576)

'''match_events.columns
match_events = match_events[['team','type','minute','location','pass_end_location','player']]
match_events = match_events[match_events['type']=='Pass']
match_events.head(30)'''
# Out:
# credentials were not supplied. open data access only
# "match_events.columns\nmatch_events = match_events[['team','type','minute','location','pass_end_location','player']]\nmatch_events = match_events[match_events['type']=='Pass']\nmatch_events.head(30)"

# %%
print([match_events['play_pattern']])
# Out:
# [0         Regular Play
# 1         Regular Play
# 2         Regular Play
# 3         Regular Play
# 4          From Corner
#              ...
# 4149    From Free Kick
# 4150    From Free Kick
# 4151      Regular Play
# 4152    From Free Kick
# 4153    From Free Kick
# Name: play_pattern, Length: 4154, dtype: object]

# %%
'''ANGULO DE PASE 0 SI ES HACIA LA PORTERIA CONTRARIA. VALOR MEJORA SI MÁS CERCANO A 0. -pi a pi, en radianes

COLUMNA ASSISTED_SHOT_ID/SHOT_ASSIST OR GOAL-ASSIST -> SI EL PASE ACABA ASISTE UN TIRO

OUTCOME VACIO (PASE COMPLETADO)

END LOCATION -> DÓNDE ACABA EL BALÓN.'''
